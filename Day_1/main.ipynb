# %% [markdown]
# # My First Jupyter Notebook
# Welcome to this interactive notebook! Below is a basic example of running Python code.

# %%
# Define two variables
a = 15
b = 27

# Calculate their sum and print the result
total = a + b
print(f"The total of {a} and {b} is: {total}")
# Out:
# The total of 15 and 27 is: 42

# %%
# Import the plotting library
import matplotlib.pyplot as plt

# Create simple data
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Plot the data
plt.plot(x, y, marker='o')
plt.title("Simple Line Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()
